# %% [markdown]
# # Caso final de repaso PLN: Solución
#
# ## Contexto
#
# La agencia de comunicación del Ministerio de Turismo de España, nos ha contactado porque quieren monitorizar que se dice de nuestro país en redes sociales y ver la opinión general y el tono de los mensajes.
# Para ello nos han pedido realizar un script donde se pueda evaluar la positividad o negatividad de los mensajes en redes sociales.
# <br>
# Como consultores les hemos propuesto una solución que analizará cada tweet publicado y le dará una puntuación entre -100% y 100% donde los valores superiores a 0% nos indican que es positivo y los valores inferiores a 0% negativos, de igual manera el 0% será neutro.
# <br>
# Para realizar una primera prueba, la agencia nos ha proporcionado lo siguiente:
# -	Archivo CSV con 500 tweets
# -	Archivo CSV con palabras negativas
# -	Archivo CSV con palabras positivas
# <br><br>
# Con esta información y materiales ya podemos realizar la tarea encomendada.<br><br>
#
# **Nota:** Este ejemplo se ha realizado utilizando los archivos extendidos de palabras

# %% [markdown]
# ## Solución al caso práctico
#
# ### Importación de librerías

# %%
import pandas as pd
pd.set_option('max_colwidth', -1)
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import re

import spacy
nlp = spacy.load('es_core_news_sm')
# Out:
# C:\Users\Juan Carlos\AppData\Local\Temp\ipykernel_7832\1129062342.py:2: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('max_colwidth', -1)

# %% [markdown]
# ### Funciones para detectar la polaridad de las palabras
# <br>
# En primer lugar debemos crear 2 funciones que detecten cuántas palabras positivas y cuántas palabras negativas contiene una frase.
# <br><br>
# Estas funciones recibirán los tokens que componen las frases a analizar, en nuestro caso cada texto del tweet.
# <br><br>
#
# #### Detectar las palabras positivas

# %%
def positivas(tokens):
    
    #Primero abrimos el fichero y eliminamos carácteres especiales
    with open('positivas_ext.csv', encoding="ANSI") as f:
        content = f.read() 
        #content = re.sub('[,\.()":;!@#$%^&*\d]|\'s|\'', '', content)
        p_list = content.replace('\n',' ').replace('  ',' ').lower().split(' ')
        
    cleaned_words = [] #Este array nos servirá para tener los lemas de las palabras positivas    
    separator = ' '
        
    for token in nlp(separator.join(p_list)):
        cleaned_words.append(token.lemma_)
    
    #Inicializamos un contador de palabras a 0 para sumar 1 cada vez que se encuentre una en la lista
    conteo = 0
    
    #Si el token está en la lista sumamos 1
    for token in tokens:
        if token in cleaned_words:
            conteo += 1
            print('POS: ' + token) #Este print puedes comentarlo para ocultar las palabras
    
    return conteo #Devolvemos la cantidad de palabras encontradas

# %% [markdown]
# #### Detectar palabras negativas
#
# Ahora simplemente tenemos que duplicar la función que tenemos para las positivas y cambiar el CSV que utilizamos para comparar

# %%
def negativas(tokens):
    
    #Primero abrimos el fichero y eliminamos carácteres especiales
    with open('negativas_ext.csv', encoding="ANSI") as f:
        content = f.read() 
        #content = re.sub('[,\.()":;!@#$%^&*\d]|\'s|\'', '', content)
        p_list = content.replace('\n',' ').replace('  ',' ').lower().split(' ')
        
    cleaned_words = [] #Este array nos servirá para tener los lemas de las palabras negativas    
    separator = ' '
        
    for token in nlp(separator.join(p_list)):
        cleaned_words.append(token.lemma_)
    
    #Inicializamos un contador de palabras a 0 para sumar 1 cada vez que se encuentre una en la lista
    conteo = 0
    
    #Si el token está en la lista sumamos 1
    for token in tokens:
        if token in cleaned_words:
            conteo += 1
            print('NEG: ' + token) #Este print puedes comentarlo para ocultar las palabras
    
    return conteo #Devolvemos la cantidad de palabras encontradas

# %% [markdown]
# ### Tokenizar frases
#
# Ahora tenemos que crear una función para tokenizar las frases que tenemos, eliminar las stopwords, y estandarizar las palabras. De esta forma nos quedaremos únicamente con las palabras que nos interesan y le dan significado a la frase.
#
# #### Tokenizar y limpiar frases

# %%
def tokenizar(frase):
    
    #Tokenizar
    tokens = word_tokenize(frase, "spanish")
    
    #Eliminar carácteres especiales, números, emojis, links ...
    tokens_alpha = [word.lower() for word in tokens if word.isalpha()]
    
    #Eliminar StopWords
    tokens_stopW = tokens_alpha[:]
    for token in tokens_alpha:
        if token in stopwords.words('spanish'):
            tokens_stopW.remove(token)
            
    #Obtener Lemas    
    cleaned_tokens = []    
    separator = ' '
        
    for token in nlp(separator.join(tokens_stopW)):
        cleaned_tokens.append(token.lemma_)
        
    
    return cleaned_tokens

# %% [markdown]
# ### Función para detectar la polaridad
#
# Ahora ya si toca crear la función para derectar la polaridad. Esta función agrupará las anteriores.

# %%
def polaridad(frase):
    
    # 1.- Tokenizamos y limpiamos la frase
    tokens = tokenizar(frase)
    
    # 2.- Obtenemos el número de tokens válidos
    tokens_num = len(tokens)
    
    # 3.- Obtenemos el número de palabras positivas y negativas de la frase
    positive_num = positivas(tokens)
    negative_num = negativas(tokens)
    
    # 4.- Calculamos la puntuación de positividad y negatividad
    postVal = positive_num / tokens_num
    negVal = (negative_num / tokens_num)*-1
    
    # 5.- Calculamos el valor final de nuesta función
    polarity = negVal + postVal
    
    # 6.- Damos el formato final de porcentaje al resultado
    polarityForm = "{:.2%}".format(polarity)
    
    return polarityForm

# %% [markdown]
# ### Probamos el funcionamiento en primer lugar con algunas frases de ejemplo

# %%
frase1 = 'El castillo ha sido conquistado violentamente en la batalla de trafalgar'
frase2 = 'Es sorprendente lo amistoso e inteligente que es este gato. Es maravilloso'

print('Ejemplo 1')
print('Frase: ' + frase1)
print('Polaridad: ' + str(polaridad(frase1)))
print('-------------------------')
print('Ejemplo 2')
print('Frase: ' + frase2)
print('Polaridad: ' + str(polaridad(frase2)))
# Out:
# Ejemplo 1
# Frase: El castillo ha sido conquistado violentamente en la batalla de trafalgar
# NEG: ser
# NEG: violentamente
# NEG: batalla
# Polaridad: -50.00%
# -------------------------
# Ejemplo 2
# Frase: Es sorprendente lo amistoso e inteligente que es este gato. Es maravilloso
# POS: sorprendente
# POS: amistoso
# POS: inteligente
# POS: maravilloso
# Polaridad: 80.00%

# %% [markdown]
# ### Prueba con los tweets
#
# Ahora cargamos el dataset con los tweets y analizamos cada uno de ellos

# %%
tweets = pd.read_csv('tweets_dataset.csv')
tweets.iloc[:5] #Mostramos los 5 primeros valores
# Out:
#    index                   ID  \
# 0  0      1459083556286713863
# 1  1      1458823365674864644
# 2  2      1459060580615176193
# 3  3      1459098007492870147
# 4  4      1458881721919750149
#
#                                                                                                                                                  text
# 0  ¡Vamos a sortear una AMD Radeon RX 6900 XT Halo Infinite Limited Edition Graphics Card! 🐍\nRequisitos para parcicipa… https://t.co/F3TzO6dhKr
# 1  En un país normal, proponer para el Constitucional a un tipo envuelto en casos de corrupción, que niega el cambio c… https://t.co/WjU7cUhb2D
# 2  🔹 11 suicidios al día\n\n🔹 Una persona se quita la vida cada 2 horas\n\n🔹 Entre ellos, el doble de niños que en 2019\n\nE… https://t.co/GpM02UQ9dv
# 3  Sánchez continúa su farsa de recuperación mientras las previsiones económicas sobre España se desploman y la cesta… https://t.co/VTygFpxduV
# 4  Sr. Sánchez, si todo es tan maravilloso, si usted es tan querido por los españoles, si España está tan bien, y los… https://t.co/sDTrOBjhAy

# %% [markdown]
# Creamos un bucle para recorrer todos los tweets del archivo y analizar su polaridad. <br><br>
# Con esto ya tendríamos completado lo solicitado

# %%
row = 1
while row < len(tweets)-1:
    
    tweet_text = tweets.iloc[row]['text']
    
    print('Tweet ' + str(tweets.iloc[row]['ID']))
    print('Contenido del tweet: ')
    print(tweet_text)
    print(' ')   
    
    polarity = polaridad(tweet_text)
    
    
    print(' ')
    print('La polaridad del texto es: ' + str(polarity))
    print('-------------------------------------')
    
    row += 1
# Out:
# Tweet 1458823365674864644
# Contenido del tweet:
# En un país normal, proponer para el Constitucional a un tipo envuelto en casos de corrupción, que niega el cambio c… https://t.co/WjU7cUhb2D
#
# NEG: tipo
# NEG: envuelto
# NEG: negar
#
# La polaridad del texto es: -27.27%
# -------------------------------------
# Tweet 1459060580615176193
# Contenido del tweet:
# 🔹 11 suicidios al día
#
# 🔹 Una persona se quita la vida cada 2 horas
#
# 🔹 Entre ellos, el doble de niños que en 2019
#
# E… https://t.co/GpM02UQ9dv
#
# NEG: suicidio
# NEG: persona
# NEG: vida
#
# La polaridad del texto es: -30.00%
# -------------------------------------
# Tweet 1459098007492870147
# Contenido del tweet:
# Sánchez continúa su farsa de recuperación mientras las previsiones económicas sobre España se desploman y la cesta… https://t.co/VTygFpxduV
#
#
# La polaridad del texto es: 0.00%
# -------------------------------------
# Tweet 1458881721919750149
# Contenido del tweet:
# Sr. Sánchez, si todo es tan maravilloso, si usted es tan querido por los españoles, si España está tan bien, y los… https://t.co/sDTrOBjhAy
#
# POS: maravilloso
# POS: querido
# POS: bien
# NEG: tanto
# NEG: tanto
# NEG: tanto
# NEG: bien
#
# La polaridad del texto es: -7.14%
# -------------------------------------
# Tweet 1458912550075219978
# Contenido del tweet:
# 🏁 ¡¡FINAL FINAL FINAAAAL EN ATENAAAAS!!
#
# La @SeFutbol se impone en tierras helenas con un gol de @Pablosarabia92 tr… https://t.co/QDUf2MA9fj
#
# NEG: final
# NEG: imponer
#
# La polaridad del texto es: -22.22%
# -------------------------------------
# Tweet 1459165378102366225
# Contenido del tweet:
# Sánchez ya tiene comprometido el hachazo fiscal a Madrid pero no podrá porque es ilegal.
#
# Bajen los impuestos a los… https://t.co/r728TKN6Gl
#
# NEG: ilegal
#
# La polaridad del texto es: -10.00%
# -------------------------------------
# Tweet 1459200635673399306
# Contenido del tweet:
# Gracias a las Fuerzas y Cuerpos de Seguridad, España es un país libre de pleno derecho, donde se protege al débil y… https://t.co/gVneulBbjK
#
# POS: gracia
# POS: seguridad
# POS: derecho
# POS: proteger
# NEG: gracia
#
# La polaridad del texto es: 25.00%
# -------------------------------------
# Tweet 1458886295795777536
# Contenido del tweet:
# Caso de @AlvaroUribeVel ha sido sometido a revisión de expertos independientes de diferentes nacionalidades entre e… https://t.co/69SSSmfYb0
#
# POS: experto
# NEG: ser
#
# La polaridad del texto es: 0.00%
# -------------------------------------
# Tweet 1458742077328662528
# Contenido del tweet:
# 💥💥💥💥💥💥💥💥💥💥💥💥💥
# 100 euros para gastar en amazon (españa) van a ser para una de las personas que haga RT 🔁 y que respo… https://t.co/6zJAlhPXJA
#
# NEG: ser
# NEG: persona
# NEG: hacer
#
# La polaridad del texto es: -30.00%
# -------------------------------------
# Tweet 1458730719665176580
# Contenido del tweet:
# 🍬 ¡SORTEO EXPRÉS 1 PACK CON BOL PARA CHUCHES! 🍬
#
# ✨Con motivo del mágico 11 del 11, ponemos en juego un pack con est… https://t.co/zpBLrkQVXW
#
# NEG: motivo
# NEG: poner
#
# La polaridad del texto es: -20.00%
# -------------------------------------
# Tweet 1458721160464531456
# Contenido del tweet:
# SORTEO ✨ ¡Gana una Switch Lite Ed. Palkia y Dialga + Ed. Dual #PokémonDiamanteBrillante y #PokémonPerlaReluciente!… https://t.co/gxanQVrFFj
#
# POS: lite
#
# La polaridad del texto es: 9.09%
# -------------------------------------
# Tweet 1458861617266012164
# Contenido del tweet:
# 🚨 OFICIAL | ¡¡YA TENEMOS EL ONCE DE ESPAÑA!!
#
# 👥 Así sale la @SeFutbol de @LUISENRIQUE21 para este partido DE VITAL… https://t.co/NYIoE78eSj
#
#
# La polaridad del texto es: 0.00%
# -------------------------------------
# Tweet 1458771026247041034
# Contenido del tweet:
# España no va a crecer este año a más del 6%, como decía el gobierno. Desgraciadamente.
#
# Ni siquiera al 5,5%. Ni aú… https://t.co/DfEt80WiyT
#
# NEG: decir
#
# La polaridad del texto es: -11.11%
# -------------------------------------
# Tweet 1458926123514011660
# Contenido del tweet:
# En @edatvoficial siempre hacemos las preguntas que incomodan a los enemigos de España y siempre recibimos la misma… https://t.co/pJaUNDuIhZ
#
# NEG: hacer
# NEG: enemigo
#
# La polaridad del texto es: -20.00%
# -------------------------------------
# Tweet 1458652117447675914
# Contenido del tweet:
# España se desmarca del impulso de Macron a las nucleares: "Habrá un cierre escalonado que respalda mayoritariamente… https://t.co/5QZD2vlOJz
#
# POS: respaldar
#
# La polaridad del texto es: 11.11%
# -------------------------------------
# Tweet 1458718053764640773
# Contenido del tweet:
# La intención del PSOE de subir el cómputo de las pensiones no fue una “serpiente de verano”. Fue un documento distr… https://t.co/aztPwIPJzB
#
#
# La polaridad del texto es: 0.00%
# -------------------------------------
# Tweet 1458710086789087234
# Contenido del tweet:
# Una de las menores tuteladas y prostituidas en Baleares fue obligada a abortar por el gobierno balear… https://t.co/0jK3OlBYgH
#
# NEG: menor
# NEG: abortar
#
# La polaridad del texto es: -25.00%
# -------------------------------------
# Tweet 1458688785311576064
# Contenido del tweet:
# La nueva Ley de Seguridad de Marlaska deja sin castigo a Podemos, ERC o Bildu por alentar disturbios. ¿Cómo era aqu… https://t.co/GuD0KuLbMm
#
# POS: seguridad
# POS: alentar
# NEG: dejar
# NEG: castigo
# NEG: disturbio
#
# La polaridad del texto es: -8.33%
# -------------------------------------
# Tweet 1458703151691968517
# Contenido del tweet:
# La vergüenza tremenda de que España bajo este gobierno delincuente y encubridor no sea capaz de investigar ni a Olt… https://t.co/sGOnDbKs5B
#
# POS: capaz
# NEG: bajo
# NEG: delincuente
#
# La polaridad del texto es: -10.00%
# -------------------------------------
# Tweet 1458720773758201859
# Contenido del tweet:
# Cualquiera diría que la actitud estaférmica de Rajoy ha dejado poso en Génova. Sólo eso explica la falta de reacció… https://t.co/f1bMqzIPNd
#
# NEG: decir
# NEG: falta
#
# La polaridad del texto es: -16.67%
# -------------------------------------
# Tweet 1458610876534050818
# Contenido del tweet:
# Ricardo Alfonsín, Embajador en España, “hoy nadie puede dudar que el Frente de Todos está más cerca del Radicalismo… https://t.co/B3EanTMlPm
#
#
# La polaridad del texto es: 0.00%
# -------------------------------------
# Tweet 1458681592747020288
# Contenido del tweet:
# La #GuardiaCivil suma una flota obsoleta a su falta crónica de personal por toda #España, sin contar con 10.160 efe… https://t.co/ZGsqHNUczh
#
# NEG: obsoleto
#
# La polaridad del texto es: -9.09%
# -------------------------------------
# Tweet 1458708080850571264
# Contenido del tweet:
# Señoría Calviño, ¿Va a mantener su mentira de q vamos a crecer un 6,5%?
#
# Bruselas certifica q con este Gobierno vam… https://t.co/prc2pYyYKE
#
# NEG: mentira
#
# La polaridad del texto es: -8.33%
# -------------------------------------
# Tweet 1458511699389079552
# Contenido del tweet:
# 🇪🇸💉 En España el 95% de los mayores de 40 años vacunados ocupan el 30% de las camas UCI por COVID
#
# En cambio, el 5%… https://t.co/WoIIECquu1
#
#
# La polaridad del texto es: 0.00%
# -------------------------------------
# Tweet 1458690205003796482
# Contenido del tweet:
# ¿Recuerdan aquello de "los fondos europeos no tienen condiciones"?
#
# La exigencia de Bruselas de gastar menos en pen… https://t.co/SqjdLTZUXu
#
# NEG: menos
#
# La polaridad del texto es: -11.11%
# -------------------------------------
# Tweet 1458714675378544656
# Contenido del tweet:
# 💸 El Gobierno deja a España al borde del precipicio con sus Presupuestos.
#
# 👉 @InesCanizares "Lo que están haciendo… https://t.co/bDsxOJJCnT
#
# NEG: dejar
#
# La polaridad del texto es: -12.50%
# -------------------------------------
# Tweet 1458713672784793600
# Contenido del tweet:
# En todo el mundo se prepara la nueva generación de centrales nucleares. Akí, pá ké.
#
# "España se desmarca de Francia… https://t.co/BNJ9Ju2oqG
#
#
# La polaridad del texto es: 0.00%
# -------------------------------------
# Tweet 1458704708806316033
# Contenido del tweet:
# La Unión Europea obliga a España a recortar las pensiones. ¿Esta es la solidaridad europea? ¿Chantajear a un país p… https://t.co/2HN0kBjIIJ
#
# POS: solidaridad
#
# La polaridad del texto es: 10.00%
# -------------------------------------
# Tweet 1458694984563974151
# Contenido del tweet:
# El Gobierno español mantiene su plan de apagar escalonadamente las siete centrales nucleares que hay en España tras… https://t.co/x1vRh5lNUe
#
# La polaridad del texto es: 0.00%
# -------------------------------------
# Tweet 1458408054261784582
# Contenido del tweet:
# ⚠️ ATENCIÓN⚠️ 50 euros para gastar en amazon (España) van a ser para una de las personas que haga RT 🔁 a este tweet… https://t.co/at27OAW76P
#
# NEG: ser
# NEG: persona
# NEG: hacer
#
# La polaridad del texto es: -30.00%
# -------------------------------------
# Tweet 1458480406307741696
# Contenido del tweet:
# Sois seres humanos maravillosos todos los que estáis poniendo y compartiendo el hastag #SOSenfermosELA
#
# Hay que ll… https://t.co/QXllRRQC36
#
# POS: humano
# POS: maravilloso
# NEG: ser
# NEG: poner
#
# La polaridad del texto es: 0.00%
# -------------------------------------
# Tweet 1458492836509274116
# Contenido del tweet:
# Gobierno de España, partidos de la oposición, partidos políticos en general.
#
# Los enfermos de ELA estamos obligados… https://t.co/4tVWWPdnM1
#
# NEG: general
# NEG: enfermo
#
# La polaridad del texto es: -20.00%
# -------------------------------------
# Tweet 1458003402496036865
# Contenido del tweet:
# EL BULO DEL GRAN APAGÓN: ESPAÑA NO ESTÁ EN RIESGO DE PARADA ELÉCTRICA GENERAL
# –Ni por capacidad: Produce 107GW, con… https://t.co/OrEpJoAQnM
#
# POS: capacidad
# NEG: riesgo
# NEG: parada
# NEG: general
# NEG: producir
#
# La polaridad del texto es: -27.27%
# -------------------------------------
# Tweet 1457673213513805824
# Contenido del tweet:
# 🔥 SORTEAZO Black de Eneba 🔥
#
# Participa aquí: https://t.co/75INL18jLO
#
# 💸 ¡Más de 2000€ en premios! 💸
#
# 🌎 Válido para España y Latinoamérica
#
# POS: premio
#
# La polaridad del texto es: 10.00%
# -------------------------------------
# Tweet 1458491206510460934
# Contenido del tweet:
# 🔴 ÚLTIMA HORA |  Bruselas obliga a España a aumentar el periodo de cálculo de las pensiones para recibir los fondos… https://t.co/MeqNuh8VUn
#
# POS: aumentar
#
# La polaridad del texto es: 9.09%
# -------------------------------------
# Tweet 1457704168882327554
# Contenido del tweet:
# Las amenazas de Marruecos son más explícitas que nunca, y permanentemente impunes como siempre.
#
# Es lógico, porque… https://t.co/T1FS9FdR0M
#
# NEG: amenaza
#
# La polaridad del texto es: -11.11%
# -------------------------------------
# Tweet 1458471261382787072
# Contenido del tweet:
# #LoÚltimo | España dio luz verde a la extradición a EE. UU. del exjefe de seguridad de Hugo Chávez https://t.co/97uJXSghhH
#
# POS: seguridad
# NEG: dar
#
# La polaridad del texto es: 0.00%
# -------------------------------------
# Tweet 1456736560188116996
# Contenido del tweet:
# España no puede seguir importando criminales, delincuentes comunes, agresores sexuales o yihadistas.
#
# Todo aquel qu… https://t.co/Xv9yLMXWFn
#
# NEG: seguir
# NEG: criminal
# NEG: delincuente
# NEG: agresor
#
# La polaridad del texto es: -33.33%
# -------------------------------------
# Tweet 1458164836265779205
# Contenido del tweet:
# La ultraderecha sigue amenazando las libertades. A un año de la recuperación de la democracia en Bolivia, os dejo m… https://t.co/KpdITYHaoi
#
# POS: libertad
# NEG: seguir
# NEG: amenazar
#
# La polaridad del texto es: -10.00%
# -------------------------------------
# Tweet 1458005586201751552
# Contenido del tweet:
# El PCE es el partido que más esfuerzo, sacrificio y militancia aportó para defender la democracia en España… Y aunq… https://t.co/c1ZAXQZdOD
#
# POS: defender
# NEG: esfuerzo
# NEG: sacrificio
#
# La polaridad del texto es: -11.11%
# -------------------------------------
# Tweet 1458494772910379012
# Contenido del tweet:
# 🦠 Incidencia acumulada COVID (casos por 100.000 habitantes en las dos últimas semanas):
#
# 🇧🇪 Bélgica —&gt; 965,7
# 🇬🇧 Rei… https://t.co/2p8pWI02dy
#
# NEG: dos
#
# La polaridad del texto es: -9.09%
# -------------------------------------
# Tweet 1458490616787177481
# Contenido del tweet:
# España lleva desde 2015 sin celebrar un Debate sobre el Estado de la Nación. ¿A qué espera Sánchez para convocarlo?… https://t.co/Qj3a7K1MqJ
#
# POS: celebrar
#
# La polaridad del texto es: 11.11%
# -------------------------------------
# Tweet 1457416453892845573
# Contenido del tweet:
# Pisotean la Constitución con total impunidad.
#
# Se ríen de los jueces.
#
# Fanfarronean con las mil formas con las qu… https://t.co/fW3Ev088Cu
#
# NEG: pisotear
# NEG: impunidad
# NEG: forma
#
# La polaridad del texto es: -30.00%
# -------------------------------------
# Tweet 1457800123312918531
# Contenido del tweet:
# DIRECTO | La OMS felicita a España por la gestión de la pandemia y la vacunación https://t.co/yi6MGj4auV https://t.co/NhJtAjcGme
#
#
# La polaridad del texto es: 0.00%
# -------------------------------------
# Tweet 1456212298457047040
# Contenido del tweet:
# ¿Cuántos muertos más serán necesarios para cambiar la política criminal en España? https://t.co/8FFfeqEIAG
#
# NEG: muerto
# NEG: criminal
#
# La polaridad del texto es: -28.57%
# -------------------------------------
# Tweet 1456693947879788546
# Contenido del tweet:
# Los nacionalistas no puede soportar q una región de España progrese sin necesidad de un trato privilegiado. Las pen… https://t.co/CJ3CLb70w7
#
# POS: privilegiado
#
# La polaridad del texto es: 9.09%
# -------------------------------------
# Tweet 1456664561885401096
# Contenido del tweet:
# Se logró el viaje a España para participar en el YouTube Rewind Hispano ❤️
#
# Gracias por la invitación @alecmolon er… https://t.co/7iCcfCVTu3
#
#
# La polaridad del texto es: 0.00%
# -------------------------------------
# Tweet 1456670001650360330
# Contenido del tweet:
# 🇪🇸🦠 Evolución semanal de la pandemia en España (se agradece difusión 🔝)
#
# 1️⃣ Incidencia más baja de Europa
# 2️⃣ Míni… https://t.co/rydr45Zflq
#
# POS: agradecer
# NEG: bajo
#
# La polaridad del texto es: 0.00%
# -------------------------------------
# Tweet 1456370659853017090
# Contenido del tweet:
# Me resulta llamativo que los primeros casos de eutanasia que se han hecho en España hayan sido enfermos de ELA.
#
# En… https://t.co/R7PSwMNfCM
#
# POS: llamativo
# NEG: llamativo
# NEG: ser
#
# La polaridad del texto es: -9.09%
# -------------------------------------
# Tweet 1456169821729665029
# Contenido del tweet:
# 🇪🇸🦠 Actualmente España es el país con menor incidencia COVID de Europa, hace una semana muchos medios y "expertos"… https://t.co/pSnVETSo5T
#
# POS: experto
# NEG: menor
# NEG: hacer
#
# La polaridad del texto es: -8.33%
# -------------------------------------
# Tweet 1456205075488071680
# Contenido del tweet:
# Cuando España cierra una puerta, Suiza abre una ventana. https://t.co/QQ0FMI03qW
#
#
# La polaridad del texto es: 0.00%
# -------------------------------------
# Tweet 1456646781522092032
# Contenido del tweet:
# Las víctimas de ETA a la UE: "¿Se imaginan ustedes un homenaje a los asesinos de Bataclán en París tras cumplir sus… https://t.co/4KrVqatKFB
#
# POS: homenaje
# NEG: asesino
#
# La polaridad del texto es: 0.00%
# -------------------------------------
# Tweet 1456531920402190337
# Contenido del tweet:
# “El candidato al Tribunal Constitucional, Enrique Arnaldo, infringió la ley para cobrar de dos universidades al mis… https://t.co/g5odb4ggpH
#
# NEG: infringir
# NEG: dos
#
# La polaridad del texto es: -18.18%
# -------------------------------------
# Tweet 1456618009372598277
# Contenido del tweet:
# Detenidos seis menores magrebíes por encerrar y amenazar a dos cuidadoras de un centro de acogida en Fuerteventura https://t.co/eG4p55QUdo
#
# NEG: menor
# NEG: amenazar
# NEG: dos
#
# La polaridad del texto es: -25.00%
# -------------------------------------
# Tweet 1456561937844744195
# Contenido del tweet:
# ⭐️ SORTEO MONSTRUOSO⭐️
#
# Nuestros amigos de @MonsterEnergyES son MUY fans de @PlayApex y os quieren hacer un 🎁👇🏻, t… https://t.co/O9C2m09JVI
#
# NEG: hacer
#
# La polaridad del texto es: -12.50%
# -------------------------------------
# Tweet 1456224679316819968
# Contenido del tweet:
# Hoy damos el primer paso hacia la aprobación de los #PGE2022. Unos presupuestos que inician una nueva etapa, que av… https://t.co/T9TiKLZejE
#
# NEG: dar
# NEG: hacia
#
# La polaridad del texto es: -18.18%
# -------------------------------------
# Tweet 1456697696467705867
# Contenido del tweet:
# Un placer volver a almorzar con Guillermo Lasso y su familia en su primer viaje a España como Presidente de Ecuador… https://t.co/GRPspErFkm
#
# POS: placer
#
# La polaridad del texto es: 9.09%
# -------------------------------------
# Tweet 1456297630959644673
# Contenido del tweet:
# En la España de @sanchezcastejon se llama progresista a lo que bendicen golpistas y  terroristas. La perversión del… https://t.co/sRvMSIVCgB
# POS: llamar
# POS: bendecir
#
# La polaridad del texto es: 22.22%
# -------------------------------------
# Tweet 1456689425769979906
# Contenido del tweet:
# Por partes:
# A. Eso no es un plató, es una sala de espera.
# B. @vox_es, la 3ra fuerza política de España,va a ir a to… https://t.co/GuV6caop9L
#
# NEG: parte
#
# La polaridad del texto es: -9.09%
# -------------------------------------
# Tweet 1456143988231188482
# Contenido del tweet:
# 🔴 El Gobierno de Pedro Sánchez "no repara en gastos" y bate el gasto histórico en asesores: 48,3 millones en nueve… https://t.co/BsvW4OdsYH
#
#
# La polaridad del texto es: 0.00%
# -------------------------------------
# Tweet 1456136502358970369
# Contenido del tweet:
# Irene Montero gasta 70.000 € en las fotos y vídeos de sus actos como ministra https://t.co/qvuX3SLClW
#
#
# La polaridad del texto es: 0.00%
# -------------------------------------
# Tweet 1456137625539158020
# Contenido del tweet:
# Sánchez evita explicar por qué hizo un Barcelona-Zaragoza en Falcon y no en AVE: «Es secreto» https://t.co/pcJRwVCug7
#
# NEG: evitar
# NEG: hacer
#
# La polaridad del texto es: -25.00%
# -------------------------------------
# Tweet 1456139738428186627
# Contenido del tweet:
# 🆘 DESAPARECIDA
# #Desaparecidos #sosdesaparecidos #Missing #España #ElEjido #Almería https://t.co/X2PDUZ55bK
#
#
# La polaridad del texto es: 0.00%
# -------------------------------------
# Tweet 1456140656167071746
# Contenido del tweet:
# Interior delegó el control del depredador de Lardero en su hermana tras salir libre: https://t.co/uA9ksR8nLY
#
# NEG: control
# NEG: depredador
#
# La polaridad del texto es: -20.00%
# -------------------------------------
# Tweet 1456148940475224065
# Contenido del tweet:
# @KRLS @washingtonpost También sería interesante saber si España apoya la medida adoptada por el Gobierno de USA respecto al Grupo NSO
#
# POS: interesante
# POS: respecto
# NEG: grupo
#
# La polaridad del texto es: 7.14%
# -------------------------------------
# Tweet 1456160282724732932
# Contenido del tweet:
# ✍🏼 "Cada vez que escuche a un político proponer una rebaja de impuestos recuerde que las becas comedor solo llegan… https://t.co/uWEXwNSlaQ
#
#
# La polaridad del texto es: 0.00%
# -------------------------------------
# Tweet 1456165345190944776
# Contenido del tweet:
# En Cataluña tampoco quieren investigar lo ocurrido en las residencias. Prefieren el silencio y no rendir cuentas. C… https://t.co/1MLAzQY50I
#
# POS: preferir
# POS: silencio
#
# La polaridad del texto es: 18.18%
# -------------------------------------
# Tweet 1456167225279270914
# Contenido del tweet:
# Los sindicatos de prisiones culpan a Marlaska del descontrol penitenciario tras el asesinato de Lardero: https://t.co/CSggraBcVh
#
# NEG: culpar
# NEG: asesinato
#
# La polaridad del texto es: -20.00%
# -------------------------------------
# Tweet 1456140761670590466
# Contenido del tweet:
# La familia del depredador sexual de Logroño lo envió al piso de Lardero tras sentirse amenazada: https://t.co/XiKjdwCPBn
#
# NEG: depredador
#
# La polaridad del texto es: -9.09%
# -------------------------------------
# Tweet 1456169405860175876
# Contenido del tweet:
# ¡Hoy es el #DíaDeLaUnesco! 👏 #España tiene una gran riqueza material e inmaterial reconocida por la #UNESCO, ¿lo sa… https://t.co/YMRKjreASB
#
# POS: riqueza
# NEG: inmaterial
#
# La polaridad del texto es: 0.00%
# -------------------------------------
# Tweet 1456164057715777547
# Contenido del tweet:
# ¿Qué supondrá que la legislación reconozca a los animales como seres sintientes? Activistas y personas expertas en… https://t.co/6hJEcJ33vh
#
# POS: experto
# NEG: ser
# NEG: persona
#
# La polaridad del texto es: -10.00%
# -------------------------------------
# Tweet 1456154818062454785
# Contenido del tweet:
# #BuenosDías. El #EjércitodeTierra es y será una herramienta resolutiva para la consecución de espacios de libertad… https://t.co/Wei3aFMMUs
#
#
# La polaridad del texto es: 0.00%
# -------------------------------------
# Tweet 1456101889993543681
# Contenido del tweet:
# ¡Las noticias! El subsecretario Hugo López-Gatell no descarta otra ola de COVID-19 en invierno; Emilio Lozoya, exdi… https://t.co/2j088EOXuv
#
#
# La polaridad del texto es: 0.00%
# -------------------------------------
# Tweet 1456159281456287748
# Contenido del tweet:
# España, uno de los 5 de países en los que el Covid-19 causó una mayor pérdida en la esperanza de vida https://t.co/5y01QdrSuW
#
# NEG: vida
#
# La polaridad del texto es: -12.50%
# -------------------------------------

# %% [markdown]
# ## Conclusión
#
# Como has observado no es demasiado complejo realizar este analizador de la polaridad, la verdadera complejidad reside en mejorar el listado de palabras. <br><br>
# Puedes probar a eliminar o añadir palabras al listado para mejorar su resultado. También puedes crear tu propio listado desde 0.
# <br><br>
# Te animamos a mejorar el listado y compartirlo con tu tutor para dejarlo disponible en los recursos para que otros compañeros puedan probar con distintos dataset de palabras.
